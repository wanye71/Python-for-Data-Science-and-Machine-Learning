# %% [markdown]
# # Web scraping

# %%
import urllib.request
import re

from bs4 import BeautifulSoup
from IPython.display import HTML

# %%
request = urllib.request.urlopen('https://xvi.com').read()
soup = BeautifulSoup(request, 'html.parser')
type(soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ### Scraping a webpage and saving your results

# %%
print(soup.prettify()[:100])
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <!-- Initalize title and data source variables -->
#  <head>
#   <!--

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# https://www.google.com/
# https://help.pornhub.com/hc/en-us/articles/4419885579795
# http://www.rtalabel.org
# javascript:void(0)
# /front/lost_password
# /front/resend_confirmation_email
# #
# mailto:support@pornhub.com
# /
# /video
# /recommended
# /video?o=ht&cc=us
# /video?o=tr
# /video?o=mv&cc=us
# /video?o=cm
# /likedvideos
# /shorties
# /categories
# /popularwithwomen
# /video?c=138
# /video?c=139
# /vr
# /video?c=28
# /categories/teen
# /video?c=29
# /video?c=17
# /video?c=35
# /video?c=181
# /video?c=27
# /video?c=65
# /video?c=111
# /categories/hentai
# /gayporn
# /transgender
# /categories
# /pornstars
# /pornstars?performerType=amateur
# /pornstars?performerType=pornstar
# /pornstars?gender=male
# /pornstars?o=t
# /pornstars?o=mv
# /channels
# /playlists
# /gifs
# /albums
# /community
# /contest_hub
# /contest_hub/viewers_choice
# /user/discover
# /contest_hub/top_earners
# /model/halloffame
# /user/search
# https://www.spicevids.com/?customUpgradeBtn&ats=eyJhIjo4NDcyMSwiYyI6NjA0NDcyMzMsIm4iOjEyMCwicyI6NjgwLCJlIjoxMDQzMCwicCI6MzkzfQ==&ad_id=bfpromo2
# https://help.pornhub.com/hc/en-us/categories/4419836212499
# https://www.uviu.com/?utm_source=pornhub&utm_medium=hamburger-menu&utm_id=pornhub-hamburgermenu&ata=phnavbar&atc=hamburger-me
# /blog
# https://www.pornhub.com/insights/
# https://www.pornhub.com/sex/
# https://pornhubapparel.com/
# https://a.adtng.com/get/10012282
# javascript:signinbox.show();updateSignUpClog('upload-video');
# javascript:signinbox.show();updateSignUpClog('upload-photo');
# None
# /front/signup?redirect=dLb1HrU3aYkleXWCWXpVvh7uQBosTmJ9cG4sOt2o6VOdHle1aXYZmiWbxP7q9jS4
# /login?redirect=WFDtMsMOhvR-eoHhCRt-rlEBbVKAOBlCv3WE0iWWb5hGw2nCD_dCl0A4nFwEDc6w
# /likedvideos
# javascript:signinbox.show();
# https://help.pornhub.com/hc/en-us/categories/4419836205203
# https://feedback.pornhub.com/forums/927769-pornhub-feature-requests-feedback
# /support
# /
# /video
# /categories
# https://livehdcams.com/?AFNO=1-60000
# /pornstars
# http://ads.trafficjunky.net/ads?zone_id=9642&format=directLP&noc=0
# /community
# /albums
# /video
# /recommended
# /video?o=ht&cc=us
# /video?o=mv&cc=us
# /video?o=tr
# /video?p=homemade&o=tr
# /shorties
# /playlists
# /channels
# /video/random
# /video?o=cm
# /contest_hub/viewers_choice
# /video?o=ht&cc=us
# /view_video.php?viewkey=6616ed5887a0b
# /view_video.php?viewkey=6616ed5887a0b
# /channels/momsteachsex
# /view_video.php?viewkey=66170295f0db5
# /view_video.php?viewkey=66170295f0db5
# /channels/blacked
# /recommended
# /view_video.php?viewkey=65fd9f85d4212
# /view_video.php?viewkey=65fd9f85d4212
# /pornstar/alex-adams
# /view_video.php?viewkey=65eb9d8217a3b
# /view_video.php?viewkey=65eb9d8217a3b
# /model/hannah-louu
# /playlists
# /view_video.php?viewkey=ph6394f4ec514a4&pkey=306423591
# /playlist/306423591
# /playlist/306423591
# /users/jwg701
# /view_video.php?viewkey=ph63bd97cf5c85d&pkey=305755651
# /playlist/305755651
# /playlist/305755651
# /users/cpot23
# /channels
# /channels/perv-mom
# /channels/perv-mom
# /channels/blacked-raw
# /channels/blacked-raw
# /video/search?search=japanese+teacher
# /video/search?search=sophia+leone
# /video/search?search=mila+solana
# /video/search?search=thigh+job
# /video/search?search=gina+wap
# /video/search?search=girthmasterr
# /video/search?search=turk
# /video/search?search=%D8%A7%DB%8C%D8%B1%D8%A7%D9%86%DB%8C+%D8%AC%D8%AF%DB%8C%D8%AF
# /categories
# /gay/categories
# /transgender
# /categories
# /video?c=28
# /categories/teen
# /video?c=29
# /video?c=17
# /video?c=35
# /video?c=181
# /video?c=27
# /video?c=65
# /video?c=111
# /categories/hentai
# /video?c=8
# /video?c=24
# /video?c=86
# /video?c=10
# /video?c=15
# /transgender
# /video?c=80
# /video?c=7
# /video?c=22
# /video?c=69
# /video/search?search=japanese+teacher
# /video/search?search=sophia+leone
# /video/search?search=mila+solana
# /video/search?search=thigh+job
# /video/search?search=gina+wap
# /video/search?search=girthmasterr
# /video/search?search=turk
# /video/search?search=%D8%A7%DB%8C%D8%B1%D8%A7%D9%86%DB%8C+%D8%AC%D8%AF%DB%8C%D8%AF
# /video/search?search=lana+rhoades+anal
# /video/search?search=jojo+austin
# /pornstars
# /pornstars?performerType=amateur
# /pornstars?performerType=pornstar
# /pornstars?gender=male
# /pornstars?o=t
# /pornstars?o=t
# /pornstar/alexis-crystal
# /pornstar/alexis-crystal
# /model/cutie-kim
# /model/cutie-kim
# /pornstars
# /pornstars
# /pornstar/natasha-nice
# /pornstar/natasha-nice
# /pornstar/skylar-vox
# /pornstar/skylar-vox
# /pornstars?o=mv
# /pornstars?o=mv
# /pornstar/sky-bri
# /pornstar/sky-bri
# /pornstar/alexis-fawx
# /pornstar/alexis-fawx
# /pornstars?breasttype=fake
# /pornstars?breasttype=natural
# /pornstars?cup=a
# /pornstars?cup=f-z
# /pornstars?hair=red
# /pornstars?hair=blonde
# /pornstars?hair=brunette
# /pornstars?piercings=yes
# /pornstars?tattoos=yes
# /pornstars?ethnicity=asian
# /pornstars?ethnicity=middle+eastern
# /pornstars?ethnicity=latin
# /pornstars?ethnicity=black
# /pornstars?ethnicity=indian
# /pornstars?ethnicity=white
# /pornstars?age=18-20
# /pornstars?age=30-40
# /pornstars?age=40-99
# /community
# /contest_hub
# /community
# /user/discover
# /user/search?verified=1&gender=2&orientation=0&relation=0&o=newest&age1=0&age2=0
# /user/search?verified=1&gender=3&orientation=0&relation=0&o=newest&age1=0&age2=0
# /user/search?verified=1&gender=1&orientation=0&relation=0&o=newest&age1=0&age2=0
# /user/discover/popular_verified_members
# /user/search?online=1&verified=1&gender=0&orientation=0&relation=0&o=newest&age1=0&age2=0
# /user/search
# /contest_hub/viewers_choice
# /contest_hub/viewers_choice/kourtney-love
# /contest_hub/viewers_choice/serenity-cox
# /contest_hub/viewers_choice/swife-katy
# /contest_hub/viewers_choice/nigonika
# /model/halloffame
# /model/jenny-lux
# /pornstar/indica-flower
# /model/lexisstar
# /pornstar/jak-knife
# /user/discover/popular_verified_members
# /model/k-white0
# /model/chloe-cum-queen
# /model/freya-white
# /model/sophiab
# /user/discover/most_viewed_users
# /model/ms-creamyfunplex
# /model/roxyshbabe
# /model/dulceatena1
# /model/chynadollbaddie
# /albums
# /gifs
# /gifs?o=tr
# /gifs?o=mv
# /albums/female-straight
# /albums/female-straight?o=tr
# /albums/female-straight?o=mv
# /upload/photo
# /gifgenerator
# /gifs?o=tr
# /gif/48574481
# /gif/48606241
# /gifs?o=mv
# /gif/48713621
# /gif/48608031
# /albums/female-straight?o=tr
# /album/72602601
# /album/76099841
# /albums/female-straight?o=mv
# /album/65929632
# /album/65124992
# /albums?search=tits
# /albums?search=ass
# /albums?search=pussy
# /albums?search=amateur
# /albums?search=dick
# /albums?search=hot
# /albums?search=teen
# /albums?search=hentai
# /albums?search=sex
# /albums?search=boobs
#
# None
# None
# None
# None
# None
# None
# None
# https://pornhubapparel.com/collections/sex-toys?utm_source=ph&utm_medium=announcement&utm_campaign=toys_next_level&utm_content=en
# /video/search?search=japanese+teacher
# /video/search?search=sophia+leone
# /model/mila-solana
# /video/search?search=thigh+job
# /model/gina-wap
# /pornstar/girthmasterr
# /video/search?search=turk
# /video/search?search=%D8%A7%DB%8C%D8%B1%D8%A7%D9%86%DB%8C+%D8%AC%D8%AF%DB%8C%D8%AF
# /video/search?search=lana+rhoades+anal
# /video/search?search=jojo+austin
# /pornstar/abella-danger
# /video/search?search=hentai+anime+uncensored
# /pornstar/rae-lil-black
# /model/snowbunny
# /video/search?search=podcast
# /view_video.php?viewkey=65d9f6fa7d426
# /model/sweetie-fox
# /view_video.php?viewkey=65d9f6fa7d426
# /view_video.php?viewkey=65e88a69cc2a2
# /channels/castingcouch-x
# /view_video.php?viewkey=65e88a69cc2a2
# /view_video.php?viewkey=ph61d6f990e7137
# /channels/bratty-sis
# /view_video.php?viewkey=ph61d6f990e7137
# /view_video.php?viewkey=657a7d0a3edee
# /channels/princess-cum
# /view_video.php?viewkey=657a7d0a3edee
# /view_video.php?viewkey=654a3cb42e907
# /model/brian-rush
# /view_video.php?viewkey=654a3cb42e907
# /view_video.php?viewkey=6603971f49a5e
# /model/karli-mergenthaler
# /view_video.php?viewkey=6603971f49a5e
# /view_video.php?viewkey=66170295f0db5
# /channels/blacked
# /view_video.php?viewkey=66170295f0db5
# /view_video.php?viewkey=6603b87da03e2
# /model/mila-solana
# /view_video.php?viewkey=6603b87da03e2
# /view_video.php?viewkey=6616ed5887a0b
# /channels/momsteachsex
# /view_video.php?viewkey=6616ed5887a0b
# /view_video.php?viewkey=6605b8b2b6281
# /model/serenity-cox
# /view_video.php?viewkey=6605b8b2b6281
# /view_video.php?viewkey=660579917c17a
# /pornstar/alex-adams
# /view_video.php?viewkey=660579917c17a
# /view_video.php?viewkey=660cab83e3820
# /model/lil_timy
# /view_video.php?viewkey=660cab83e3820
# /view_video.php?viewkey=66031efe11c60
# /model/karli-mergenthaler
# /view_video.php?viewkey=66031efe11c60
# /view_video.php?viewkey=65c84dd916253
# /model/gina-wap
# /view_video.php?viewkey=65c84dd916253
# /view_video.php?viewkey=661727a8ce1c9
# /pornstar/alex-adams
# /view_video.php?viewkey=661727a8ce1c9
# /view_video.php?viewkey=6600d816a70d7
# /pornstar/jak-knife
# /view_video.php?viewkey=6600d816a70d7
# /view_video.php?viewkey=66062a95133ec
# /model/creamformebaby
# /view_video.php?viewkey=66062a95133ec
# /view_video.php?viewkey=65d6759132dc3
# /channels/property-sex
# /view_video.php?viewkey=65d6759132dc3
# /view_video.php?viewkey=65f2209777262
# /model/tabby-noname
# /view_video.php?viewkey=65f2209777262
# /view_video.php?viewkey=658b408cb9730
# /channels/bratty-sis
# /view_video.php?viewkey=658b408cb9730
# /view_video.php?viewkey=657a7dcde19ee
# /channels/nf-busty
# /view_video.php?viewkey=657a7dcde19ee
# /view_video.php?viewkey=64ebecc72c6aa
# /pornstar/dirtydanii_69
# /view_video.php?viewkey=64ebecc72c6aa
# /view_video.php?viewkey=66014cb5a088b
# /model/karli-mergenthaler
# /view_video.php?viewkey=66014cb5a088b
# /view_video.php?viewkey=654722c7281f6
# /pornstar/alex-adams
# /view_video.php?viewkey=654722c7281f6
# /view_video.php?viewkey=65d42a5c0b305
# /model/ariana-lopes
# /view_video.php?viewkey=65d42a5c0b305
# /view_video.php?viewkey=660ec9350ffa0
# /model/tim_deen
# /view_video.php?viewkey=660ec9350ffa0
# /view_video.php?viewkey=65c999f8e675e
# /channels/fucked-hard-18
# /view_video.php?viewkey=65c999f8e675e
# /view_video.php?viewkey=6615c5622f60a
# /channels/property-sex
# /view_video.php?viewkey=6615c5622f60a
# /view_video.php?viewkey=65d8f868bcff4
# /channels/cam-soda
# /view_video.php?viewkey=65d8f868bcff4
# /view_video.php?viewkey=65fdc6946a4f3
# /channels/perv-mom
# /view_video.php?viewkey=65fdc6946a4f3
# /view_video.php?viewkey=65cf6fa6ebf83
# /channels/milfed
# /view_video.php?viewkey=65cf6fa6ebf83
# /view_video.php?viewkey=6623e35da41c1
# /model/francy-rossi
# /view_video.php?viewkey=6623e35da41c1
# /view_video.php?viewkey=661cd6c9be859
# /model/peachy-catsnack
# /view_video.php?viewkey=661cd6c9be859
# /view_video.php?viewkey=661e3ef7d3906
# /channels/oops-family
# /view_video.php?viewkey=661e3ef7d3906
# /view_video.php?viewkey=661c2318096f7
# /model/mickliter
# /view_video.php?viewkey=661c2318096f7
# /view_video.php?viewkey=661d7a2e99624
# /model/evandmikee
# /view_video.php?viewkey=661d7a2e99624
# /view_video.php?viewkey=661fd2bf5f62f
# /model/expressiagirl
# /view_video.php?viewkey=661fd2bf5f62f
# /view_video.php?viewkey=661826353dc30
# /pornstar/cail-brodnevski
# /view_video.php?viewkey=661826353dc30
# /view_video.php?viewkey=66170295f0db5
# /channels/blacked
# /view_video.php?viewkey=66170295f0db5
# /view_video.php?viewkey=661ed45e24372
# /channels/dad-crush
# /view_video.php?viewkey=661ed45e24372
# /view_video.php?viewkey=66182d2f3439d
# /model/sleepoverfriends
# /view_video.php?viewkey=66182d2f3439d
# /view_video.php?viewkey=6617f57bd7fa9
# /model/vibewithmommy
# /view_video.php?viewkey=6617f57bd7fa9
# /view_video.php?viewkey=66150846b1e7a
# /model/nolube
# /view_video.php?viewkey=66150846b1e7a
# /view_video.php?viewkey=6617c17b03771
# /channels/dancingbear
# /view_video.php?viewkey=6617c17b03771
# /view_video.php?viewkey=661f88ee5e954
# /channels/adulttime
# /view_video.php?viewkey=661f88ee5e954
# /view_video.php?viewkey=662536293138d
# /model/homemadevideosxx
# /view_video.php?viewkey=662536293138d
# /view_video.php?viewkey=66196a40abd91
# /channels/naughtyamerica
# /view_video.php?viewkey=66196a40abd91
# /view_video.php?viewkey=661d7cc7e18dd
# /model/jackplusjill
# /view_video.php?viewkey=661d7cc7e18dd
# /view_video.php?viewkey=661eee102b1b7
# /channels/house-humpers
# /view_video.php?viewkey=661eee102b1b7
# /view_video.php?viewkey=6622c961707dd
# /channels/vixen-plus
# /view_video.php?viewkey=6622c961707dd
# /view_video.php?viewkey=661bd802dc1f7
# /model/sex_associates
# /view_video.php?viewkey=661bd802dc1f7
# /view_video.php?viewkey=661727a8ce1c9
# /pornstar/alex-adams
# /view_video.php?viewkey=661727a8ce1c9
# /view_video.php?viewkey=661b7c99c59d7
# /channels/transfixed
# /view_video.php?viewkey=661b7c99c59d7
# /view_video.php?viewkey=6616e073b5deb
# /channels/pure-taboo
# /view_video.php?viewkey=6616e073b5deb
# /view_video.php?viewkey=66183847b9f5f
# /channels/tushy
# /view_video.php?viewkey=66183847b9f5f
# /view_video.php?viewkey=661be54842835
# /channels/bambulax
# /view_video.php?viewkey=661be54842835
# /view_video.php?viewkey=662278a96f2a7
# /channels/mylf
# /view_video.php?viewkey=662278a96f2a7
# /view_video.php?viewkey=66183152115e3
# /channels/tushy
# /view_video.php?viewkey=66183152115e3
# /view_video.php?viewkey=66228c3a7d733
# /model/amnahentai
# /view_video.php?viewkey=66228c3a7d733
# /view_video.php?viewkey=661845db5dfb8
# /channels/vixen
# /view_video.php?viewkey=661845db5dfb8
# /view_video.php?viewkey=6622f40eea825
# /model/miaipanema
# /view_video.php?viewkey=6622f40eea825
# /view_video.php?viewkey=661ae6becd4e6
# /model/anna_cherry7
# /view_video.php?viewkey=661ae6becd4e6
# /view_video.php?viewkey=661c817c38c1d
# /model/jacknbecca
# /view_video.php?viewkey=661c817c38c1d
#
# /video
# /video?page=2
# /video?page=3
# /video?page=4
# /video?page=5
# /video?page=10
# /video
# https://www.pornhub.com/sitemap
# https://www.pornhub.com/information/terms
# https://www.pornhub.com/information/privacy
# https://www.pornhub.com/information/dmca
# https://www.pornhub.com/information/2257
# https://www.pornhub.com/information/eu_dsa
# https://www.pornhub.com/information/recommender
# /partners/cpp
# /information/advertising
# /webmasters
# /partners/models
# /press
# /content-removal
# /support
# https://help.pornhub.com/hc/en-us/categories/4419836205203
# https://help.pornhub.com/hc/en-us/categories/4419836212499
# https://help.pornhub.com/hc/en-us/articles/4419885579795
# https://feedback.pornhub.com/forums/927769-pornhub-feature-requests-feedback
# /blog
# //www.pornhub.com/insights/
# //www.pornhub.com/sex/
# None
# None
# https://de.pornhub.com/
# https://fr.pornhub.com/
# https://es.pornhub.com/
# https://it.pornhub.com/
# https://pt.pornhub.com/
# https://pl.pornhub.com/
# https://rt.pornhub.com/
# https://jp.pornhub.com/
# https://nl.pornhub.com/
# https://cz.pornhub.com/
# https://cn.pornhub.com/
# https://twitter.com/pornhub
# https://www.reddit.com/r/Pornhub/
# https://discord.gg/pornhub
# /information/rating

# %%
print(soup.get_text())
# Out:
# analytics.usa.gov | The US government's web traffic.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             An official website of the United States government
#
# Here’s how you know
#
#
# Here’s how you know
#
#
#
#
#
#
#
#
#
# Official websites use .govA
#               .gov website belongs to an official government
#               organization in the United States.
#
#
#
#
#
#
#
# Secure .gov websites use HTTPSA
#               lock (
#
# Lock
#
#                     Locked padlock icon
#
#
#  ) or https:// means you’ve safely connected to
#               the .gov website. Share sensitive information only on official,
#               secure websites.
#
#
#
#
#
#
#
#
#
#
#  analytics.usa.gov
#
#
# Select an agency to display results
#
# Government-Wide
#
#         Agency for International Development
#
#
#         Department of Agriculture
#
#
#         Department of Commerce
#
#
#         Department of Defense
#
#
#         Department of Education
#
#
#         Department of Energy
#
#
#         Department of Health and Human Services
#
#
#         Department of Homeland Security
#
#
#         Department of Housing and Urban Development
#
#
#         Department of Justice
#
#
#         Department of Labor
#
#
#         Department of State
#
#
#         Department of Transportation
#
#
#         Department of Veterans Affairs
#
#
#         Department of the Interior
#
#
#         Department of the Treasury
#
#
#         Environmental Protection Agency
#
#
#         Executive Office of the President
#
#
#         General Services Administration
#
#
#         National Aeronautics and Space Administration
#
#
#         National Archives and Records Administration
#
#
#         National Science Foundation
#
#
#         Nuclear Regulatory Commission
#
#
#         Office of Personnel Management
#
#
#         Small Business Administration
#
#
#         Social Security Administration
#
#
#         United States Postal Service
#
#
#
#
#
#
# About
# •
#
#
# Definitions
# •
#
#
# Data
# •
# API
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#         people on
#
#
#           U.S. Federal Government
#
#
#         websites and apps in the last 30 minutes
#
#
#
#
#
#
#
#       User Locations and Languages in the Last 30 Minutes
#
#
#
#
# Cities
#
#
#
#
#
# Countries
#
#
#
#
# United States & Territories
#
#
#
# International
#
#
#
#
# Languages
#
#
#
#
#
#
#
#
#
#       Historical Data and Trends
#
#
#
#
#
#
#       Daily Sessions in the Past 30 Days
#
#
#
#
#
#
#
#
#     There were ... sessions in the
#     last 30 days.
#
#
#
#
#
#
#
# Average Engagement Time
#             Per Session
#
#
#
#
#
#
#
#
# Percent of Engaged Sessions
#
#
#
#
#
#
#
#
#
#
#
#       Top Traffic Sources in the Last 30 Days
#
#
#
#
#
# Top Channels
#
#
#
#
#
#
# Top Sources/Media
#
#
#
#
#
#
#
#
#
#       User Device Demographics in the Last 30 Days
#
#
#
#
#
# Devices
#
#
#
#
#
#
# Web Browsers
#
#
#
#
#
#
# Operating Systems
#
#
#
#
# Windows
#
#
#
#
#
#
#
#
#
#
# Top Web Pages and App Screens
#
#
#
#
#         30 mins
#
#
#
#
#         7 Days
#
#
#
#
#         30 Days
#
#
#
#
#
# People on a single, specific page or app screen in
#       the last 30 minutes. Hostnames are not currently reported in real-time,
#       so only page title and screen name information is available.
#
#
#
#
#
#
#       Sessions over the last week on hostnames, including
#       traffic to all web pages and app screens within that hostname.
#
#
#
#
#
#       Sessions over the last month on hostnames, including
#       traffic to all web pages and app screens within that hostname.
#       Download the full dataset.
#
#
#
#
#
#
#
#       Top Downloads Yesterday
#
#
# Total file downloads yesterday on  hostnames.
#
#
#
#
#
#
#
#
#
# About this Site
#
#         These data provide a window into how people are interacting with the
#         government online. The data come from a unified Google Analytics account
#         for U.S. federal government agencies known as the
#         Digital Analytics Program. This program
#         helps government agencies understand how people find,
#         access, and use government services online. The program does not track
#         individuals and anonymizes the IP addresses of visitors.
#
#
#         Not every government website is represented in these data. Currently,
#         the Digital Analytics Program collects web traffic from more than 500
#         federal government second level domains,
#
#         across
#
#         approximately 7000 total hostnames,
#         including every executive branch cabinet department. We continue to
#         pursue and add more sites frequently; to add your site,
#         email the Digital Analytics Program.
#
#
#
#
#  Feedback
#
#
#
# Download the data
#
#         You can
#         download the data here. Available
#         in JSON and CSV format.
#
#
#         Additionally, you can access data via
#         API
#         (currently in Beta).
#
# A note on sampling
#
#         Due to varying GA4 sampling thresholds, high data cardinality, and the
#         volume of DAP data across its sub-properties, real-time and historical
#         data reports are subject to sampling. These data are intended to
#         represent high-level trends only and provide general insights into
#         online visitor behavior.
#
#
#
#
#
#
#
#
#             Have a question or problem?
#              Get in touch.
#
#
#
#             Suggest a feature or report an issue
#
#
#
#
#
#
#               View application code on GitHub
#
#
#
#
#               View code for the data on GitHub
#
#
#
#
#
#
#
#
#
#
#
#
#
# analytics.usa.gov
#
#           Analytics.usa.gov is a product of GSA’s
#           Digital Analytics Program.
#
#
#
#
#
#
#
#
# About GSA
#
#
# Accessibility statement
#
#
# FOIA requests
#
#
# No FEAR Act data
#
#
# Office of the Inspector
#             General
#
#
# Performance reports
#
#
# Privacy policy
#
#
#
#
#
#
#
#         Looking for U.S. government information and services?
#
# Visit USA.gov

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="xv-responsive" lang="en">
#  <head>
#   <title>
#    Free Porn, Sex, Tube Videos, XXX Pics, Pussy in Porno Movies - XNXX.COM
#   </title>
#   <link href="https://amp.xnxx.com" rel="amphtml"/>
#   <meta charset="utf-8"/>
#   <!--[if IE]><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><![endif]-->
#   <meta content="width=device-width, initial-scale=1.0" name="viewport">
#    <meta content="XNXX delivers free sex movies and fast free porn videos (tube porn). Now 10 million+ sex vids available for free! Featuring hot pussy, sexy girls in xxx rated porn clips." name="description"/>
#    <meta content="porn,porn movies,free porn,free porn movies,sex,porno,free sex,tube porn,tube,videos,full porn,xxnx,xnxxx,xxx,pussy," name="keywords"/>
#    <meta content="RTA-5042-1996-1400-1577-RTA" name="RATING"/>
#    <meta content="telephone=no" name="format-detection"/>
#    <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#    <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#    <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#    <link href="/manifest.json" rel="manifest"/>
#    <link href="https://www.xnxx.com/" hreflang="x-default" rel="alternate">
#     <link href="https://www.xnxx104.com/" hreflang="bn" rel="alternate">
#      <link href="https://www.xnxx104.com/" hreflang="en-in" rel="alternate">
#       <link href="https://www.xnxx104.com/" hreflang="gu" rel="alternate">
#        <link href="https://www.xnxx104.com/" hreflang="hi" rel="alternate">
#         <link href="https://www.xnxx104.com/" hreflang="kn" rel="alternate"/>
#         <link href="https://www.xnxx104.com/" hreflang="ml" rel="alternate"/>
#         <link href="https://www.xnxx104.com/" hreflang="mr" rel="alternate"/>
#         <link href="https://www.xnxx104.com/" hreflang="or" rel="alternate"/>
#         <link href="https://www.xnxx104.com/" hreflang="ta" rel="alternate"/>
#         <link href="https://www.xnxx104.com/" hreflang="te" rel="alternate"/>
#         <link color="#000090" href="/safari-pinned-tab.svg" rel="mask-icon"/>
#         <meta content="#000090" name="theme-color"/>
#         <link href="https://static-cdn77.xnxx-cdn.com/v-9332eb299a4/v3/css/xnxx/front.css" id="xnxxstyles" rel="stylesheet"/>
#         <script>
#          if(!window.xv){window.xv={};}window.xv.conf={"sitename":"xnxx","domains":{"slave":"https://www.xnxx.com","static":"https://static-cdn77.xnxx-cdn.com","premium":"https://www.xnxx.gold","info":"https://info.xnxx.com"},"dyn":{"exoclick":{"mobilerectangle":100,"footer":100,"square":100,"video":100,"native":100,"interstitial":100,"interstitialfull":100,"popup":100,"featurephone":100},"slcams":true,"pagefilter":"straight","page_main_cat":"straight","no_main_cat":false,"user_old_main_cat":false,"suportHls":true,"allowQuickies":false,"i18nvers":{"front":{"en":"f262900bd9c"},"xvplayer":{"en":"94dc8679653"},"video_ads_plugin":{"en":"50c1ce66664"},"info":{"en":"3bffb624aa4"},"blog":{"en":"bc6aa5b04a5"},"sheer_chat":{"en":"dbfc1484010"}},"nb_thumbs_cols":[],"gentime":1713926983,"ip":"107.202.185.44","country":"US","lazyloading":false,"is_robot":true,"browser":"python script","show_premium_info_frame":true,"show_premium_discount":null,"enafeats":[],"disfeats":[],"donewizs":[],"user_main_cat":"straight","user_main_cat_forced":false,"chat":{"enabled":false,"is_sheer_creator":false},"forcedcountry":false,"version_trsl":"USA","version_flag":"us","vp":{"allowed":false},"ls":{"buttons":[{"name":"language"},{"name":"version"},{"name":"currency"},{"name":"sep"},{"name":"sep"},{"name":"nb_vids_per_row"},{"name":"auto_translate_title"},{"name":"suggests"}]},"currencies":[{"id":"USD","url":"\/change-currency\/USD","short_name":"$","is_current":true},{"id":"EUR","url":"\/change-currency\/EUR","short_name":"\u20ac","is_current":false},{"id":"AED","url":"\/change-currency\/AED","short_name":"AED","is_current":false},{"id":"AFN","url":"\/change-currency\/AFN","short_name":"AFN","is_current":false},{"id":"XCD","url":"\/change-currency\/XCD","short_name":"EC$","is_current":false},{"id":"ALL","url":"\/change-currency\/ALL","short_name":"ALL","is_current":false},{"id":"AMD","url":"\/change-currency\/AMD","short_name":"AMD","is_current":false},{"id":"ANG","url":"\/change-currency\/ANG","short_name":"ANG","is_current":false},{"id":"AOA","url":"\/change-currency\/AOA","short_name":"AOA","is_current":false},{"id":"ARS","url":"\/change-currency\/ARS","short_name":"ARS","is_current":false},{"id":"AUD","url":"\/change-currency\/AUD","short_name":"A$","is_current":false},{"id":"AWG","url":"\/change-currency\/AWG","short_name":"AWG","is_current":false},{"id":"AZN","url":"\/change-currency\/AZN","short_name":"AZN","is_current":false},{"id":"BAM","url":"\/change-currency\/BAM","short_name":"BAM","is_current":false},{"id":"BBD","url":"\/change-currency\/BBD","short_name":"BBD","is_current":false},{"id":"BDT","url":"\/change-currency\/BDT","short_name":"BDT","is_current":false},{"id":"XOF","url":"\/change-currency\/XOF","short_name":"F\u202fCFA","is_current":false},{"id":"BGN","url":"\/change-currency\/BGN","short_name":"BGN","is_current":false},{"id":"BHD","url":"\/change-currency\/BHD","short_name":"BHD","is_current":false},{"id":"BIF","url":"\/change-currency\/BIF","short_name":"BIF","is_current":false},{"id":"BMD","url":"\/change-currency\/BMD","short_name":"BMD","is_current":false},{"id":"BND","url":"\/change-currency\/BND","short_name":"BND","is_current":false},{"id":"BOB","url":"\/change-currency\/BOB","short_name":"BOB","is_current":false},{"id":"BRL","url":"\/change-currency\/BRL","short_name":"R$","is_current":false},{"id":"BSD","url":"\/change-currency\/BSD","short_name":"BSD","is_current":false},{"id":"INR","url":"\/change-currency\/INR","short_name":"\u20b9","is_current":false},{"id":"NOK","url":"\/change-currency\/NOK","short_name":"NOK","is_current":false},{"id":"BWP","url":"\/change-currency\/BWP","short_name":"BWP","is_current":false},{"id":"BYN","url":"\/change-currency\/BYN","short_name":"BYN","is_current":false},{"id":"BZD","url":"\/change-currency\/BZD","short_name":"BZD","is_current":false},{"id":"CAD","url":"\/change-currency\/CAD","short_name":"CA$","is_current":false},{"id":"CDF","url":"\/change-currency\/CDF","short_name":"CDF","is_curr ...
#         </script>
#         <script src="https://static-cdn77.xnxx-cdn.com/v-5e7c638b684/v3/js/skins/min/xnxx.header.static.js">
#         </script>
#        </link>
#       </link>
#      </link>
#     </link>
#    </link>
#   </meta>
#  </head>
#  <body class="home">
#   <div id="header">
#    <header>
#     <div class="topbar">
#      <a class="icon-header-bg transition mobile-show" href="#" id="header-mobile-search-toggle" title="Toggle search">
#       <span class="icon search">
#       </span>
#      </a>
#      <a class="icon-header-bg transition mobile-show" href="#" id="header-mobile-menu-toggle" title="Toggle menu">
#       <span class="icon hamburger">
#       </span>
#      </a>
#      <div class="logo-xnxx">
#       <a class="transition" href="/">
#        <img alt="XNXX.COM" class="no-blur" src="https://static-cdn77.xnxx-cdn.com/v3/img/skins/xnxx/logo-xnxx.png"/>
#       </a>
#      </div>
#      <div class="mobile-hide" id="language-and-version">
#       <ul>
#        <li>
#         <a href="#" id="language-switcher">
#          Language
#          <span class="flag-small flag-us">
#          </span>
#          <span class="icon-f icf-caret-down">
#          </span>
#         </a>
#        </li>
#        <li>
#         <a class="country-switch" data-country="us" href="#">
#          Content
#          <span class="flag-small flag-us">
#          </span>
#          <span class="icon-f icf-caret-down">
#          </span>
#         </a>
#        </li>
#        <li>
#         <a class="mc-update-infos" href="#" id="main-cat-switcher">
#          <span class="mcui-name">
#           Straight
#          </span>
#          <span class="icon-f icf-sexe-woman-v2 mcui-picto">
#          </span>
#          <span class="icon-f icf-caret-down">
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="slogan">
#       100% Free Porn Movies and Sex Content
#      </div>
#      <form action="/" class="form-inline mobile-menu mobile-hide" id="xnxx-search-bar" method="get">
#       <button class="mobile-show btn btn-link" id="xnxx-search-bar-close" type="button">
#        <span class="icon-f icf-close-thin">
#        </span>
#       </button>
#       <div class="form-group">
#        <input class="form-control search-input" id="k" maxlength="2048" name="k" placeholder="Search..." type="text" value=""/>
#       </div>
#       <button class="btn btn-primary" type="submit">
#        Search
#       </button>
#       <div class="mobile-show side-categories-block" id="mobile-categories">
#        <ul class="side-cat-order-select list-unstyled" id="mobile-cat-order-select">
#         <li>
#          <a data-order="order-top-asc" href="#">
#           Top
#          </a>
#         </li>
#         <li>
#          <a data-order="order-az-asc" href="#">
#           <span>
#           </span>
#           A - Z
#          </a>
#         </li>
#        </ul>
#        <div class="hidden cat-history-legend" id="mobile-cat-history-legend">
#         <span>
#          ?
#         </span>
#         <div class="hidden">
#          <p>
#           This menu's updates are based on your activity. The data is only saved locally (on your computer) and never transferred to us. You can click these links to
#           <a data-action="clear-history" data-follow="nofollow" href="#">
#            clear your history
#           </a>
#           or
#           <a data-action="disable-history" data-follow="nofollow" href="#">
#            disable it
#           </a>
#           .
#          </p>
#         </div>
#        </div>
#        <ul class="side-cat-list list-unstyled" id="mobile-cat-list">
#        </ul>
#       </div>
#      </form>
#     </div>
#     <div id="site-nav">
#      <div class="header-icons">
#       <div id="listing-settings">
#        <div class="btn" title="Settings">
#         <span class="icon-f icf-cog">
#         </span>
#        </div>
#       </div>
#       <a class="bookmark-link btn mobile-hide" href="#" target="_self" title="BOOKMARK XNXX VIDEOS">
#        <span class="icon bookmark">
#        </span>
#       </a>
#      </div>
#      <a class="gold-plate" href="https://www.xnxx.gold/gold/videos" id="header-mobile-gold" title="XNXX GOLD">
#       GOLD
#      </a>
#      <a class="mobile-show-inline-block header-mobile-link" href="https://cams.xnxx.com/?language=en&amp;mp_code=d4vnm&amp;utm_content=d4vnm" id="header-mobile-live-cam" target="_blank" title="Live Cams">
#       <span class="icon-f icf-xcams">
#       </span>
#       <span class="label sm-col-only-show-inline md-col-only-show-inline">
#        Live Cams
#       </span>
#      </a>
#      <a class="mobile-show-inline-block header-mobile-link nutaku-games" href="https://xnxx.nutaku.net/wl/gate/" target="_blank" title="Porn Games">
#       <span class="icon-f icf-gamepad">
#       </span>
#       <span class="label md-col-only-show-inline">
#        Porn Games
#       </span>
#      </a>
#      <a class="mobile-show-inline-block header-mobile-link" href="https://www.xdating.com/" target="_blank">
#       <span class="icon-f icf-hearts-o" title="Dating">
#       </span>
#       <span class="label md-col-only-show-inline">
#        Dating
#       </span>
#      </a>
#      <a class="mobile-show-inline-block mc-update-infos" href="#" id="main-cat-switcher-mobile">
#       <span class="icon-f icf-sexe-woman-v2 mcui-picto">
#       </span>
#       <span class="md-col-only-show-inline">
#        Straight
#       </span>
#       <span class="icon-f icf-caret-down">
#       </span>
#      </a>
#      <div class="mobile-hide mobile-menu" id="mobile-menu">
#       <ul>
#        <li class="mobile-show">
#         <a href="/history">
#          History
#         </a>
#        </li>
#        <li>
#         <a href="/best">
#          Best Of
#         </a>
#        </li>
#        <li>
#         <a href="/hits">
#          Hits
#         </a>
#        </li>
#        <li>
#         <a href="/tags">
#          Tags
#         </a>
#        </li>
#        <li>
#         <a href="https://multi.xnxx.com">
#          Pictures
#         </a>
#        </li>
#        <li>
#         <a class="live-cams" href="https://cams.xnxx.com/?language=en&amp;mp_code=d4vni&amp;utm_content=d4vni">
#          Live Cams
#         </a>
#        </li>
#        <li>
#         <a href="https://www.sexstories.com">
#          Sex Stories
#         </a>
#        </li>
#        <li>
#         <a href="https://forum.xnxx.com">
#          Forum
#         </a>
#        </li>
#        <li>
#         <a href="/pornstars">
#          Pornstars
#         </a>
#        </li>
#        <li>
#         <a class="nutaku-games" href="https://xnxx.nutaku.net/wl/gate/" target="_blank">
#          Games
#         </a>
#        </li>
#        <li>
#         <a href="https://www.xdating.com/">
#          Dating
#         </a>
#        </li>
#        <li>
#         <a class="gold-plate" href="https://www.xnxx.gold/gold/videos?pmsc=menu&amp;pmln=en&amp;sxcaf=8KVUNHU4PG_menu__">
#          GOLD
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </header>
#   </div>
#   <div id="content">
#    <div class="mobile-hide side-categories-block" id="side-categories">
#     <ul class="list-unstyled">
#      <li>
#       <ul class="side-cat-order-select list-unstyled" id="side-cat-order-select">
#        <li>
#         <a data-order="order-top-asc" href="#">
#          Top
#         </a>
#        </li>
#        <li>
#         <a data-order="order-az-asc" href="#">
#          <span>
#          </span>
#          A - Z
#         </a>
#        </li>
#       </ul>
#       <div class="hidden cat-history-legend" id="side-cat-history-legend">
#        <span>
#         ?
#        </span>
#        <div class="hidden">
#         <p>
#          This menu's updates are based on your activity. The data is only saved locally (on your computer) and never transferred to us. You can click these links to
#          <a data-action="clear-history" data-follow="nofollow" href="#">
#           clear your history
#          </a>
#          or
#          <a data-action="disable-history" data-follow="nofollow" href="#">
#           disable it
#          </a>
#          .
#         </p>
#        </div>
#       </div>
#       <ul class="side-cat-list list-unstyled" id="side-cat-list">
#       </ul>
#      </li>
#      <li>
#       <a data-follow="nofollow" href="/tags">
#        More... (full list)
#       </a>
#      </li>
#     </ul>
#     <script>
#      xv.cats.init_write_stored_order("side-cat-list","side-cat-order-select","side-cat-history-legend");
#     </script>
#    </div>
#    <div id="content-thumbs">
#     <div class="clear-infobar">
#      <strong class="infobar-title">
#       FREE PORN VIDEOS
#      </strong>
#      <span class="pull-right mobile-hide">
#       <strong>
#        <a href="/best/">
#         10,368,589
#        </a>
#       </strong>
#       videos total
#      </span>
#      <a class="mobile-show pull-right" href="/best/">
#       <strong>
#        10,368,589 more &gt;&gt;&gt;
#       </strong>
#      </a>
#     </div>
#     <div id="content-ad-top-zone-contener">
#      <div id="content-ad-top-zone">
#      </div>
#     </div>
#     <div class="mozaique cust-nb-cols" id="home-cat-list">
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#      <div class="thumb-block thumb-cat">
#       <div class="thumb-inside">
#       </div>
#      </div>
#     </div>
#     <script type="text/javascript">
#      try {xv.cats.write_thumb_block_list([{"i":"https:\/\/gcore-pic.xnxx-cdn.com\/videos\/thumbs169xnxx\/6e\/13\/05\/6e1305146e41e1de14fcc1b92894a59f-1\/6e1305146e41e1de14fcc1b92894a59f.24.jpg","u":"\/todays-selection","tf":"Today&#039;s selection","t":"Today&#039;s selection","n":0,"w":1,"c":19},{"i":"https:\/\/gcore-pic.xnxx-cdn.com\/videos\/thumbs169xnxx\/c5\/8b\/75\/c58b750d390b5d122c6f7755ca677791\/c58b750d390b5d122c6f7755ca677791.13.jpg","c":19,"u":"\/search\/familial_relations?id=80698571","tf":"Family","t":"Family","n":"60,216","w":150,"ty":"cat","id":79},{"i":"https:\/\/cdn77-pic.xnxx-cdn.com\/videos\/thumbs169xnxx\/15\/35\/a6\/1535a615999323c05c5ef9651d9eed5b-1\/1535a615999323c05c5ef9651d9eed5b.11.jpg","c":10,"u":"\/search\/hardcore?top&id=74656345","tf":"Hardcore","t":"Hardcore","n":"450,702","w":150,"ty":"search"},{"i":"https:\/\/cdn77-pic.xnxx-cdn.com\/videos\/thumbs169xnxx\/5d\/90\/82\/5d9082aab1f70ee67bb110f3f6293eea\/5d9082aab1f70ee67bb110f3f6293eea.30.jpg","c":10,"u":"\/search\/black_woman?id=68452305","tf":"Black Girls","t":"Black Girls","n":"224,430","w":149,"ty":"cat","id":30},{"i":"https:\/\/cdn77-pic.xnxx-cdn.com\/videos\/thumbs169xnxx\/72\/57\/17\/7257170eca113c0696ab798e2df98b88\/7257170eca113c0696ab798e2df98b88.20.jpg","c":10,"u":"\/search\/doggystyle?top&id=37369543","tf":"Doggystyle","t":"Doggystyle","n":"156,681","w":149,"ty":"search"},{"i":"https:\/\/cdn77-pic.xnxx-cdn.com\/videos\/thumbs169xnxx\/3d\/53\/18\/3d53185173815ab959aaea9b37346cf5\/3d53185173815ab959aaea9b37346cf5.4.jpg","c":10,"u":"\/search\/milf?id=77527375","tf":"Milf","t":"Milf","n":"223,150","w":148,"ty":"cat","id":19},{"i":"https:\/\/cdn77-pic.xnxx-cdn.com\/videos\/thumbs169xnxx\/73\/77\/fa\/7377fa3728c4c67723238377c6d9e7a5-1\/7377fa3728c4c67723238377c6d9e7a5.29.jpg","c":10,"u":"\/search\/masturbation?top&id=41719447","tf":"Masturbation","t":"Masturbation","n":"279,289","w":148,"ty":"search"},{"i":"https:\/\/gcore-pic.xnxx-cdn.com\/videos\/thumbs169xnxx\/83\/07\/67\/830767c1a45d8a2f6ffc84f9233037b2-1\/830767c1a45d8a2f6ffc84f9233037b2.4.jpg","c":19,"u":"\/search\/big_ass?id=70731293","tf":"Big Ass","t":"Big Ass","n":"383,436","w":147,"ty":"cat","id":24},{"i":"https:\/\/cdn77-pic.xnxx-cdn.com\/videos\/thumbs169xnxx\/fb\/72\/4b\/fb724b44b1951a872273b3ce72d27e00\/fb724b44b1951a872273b3ce72d27e00.19.jpg","c":10,"u":"\/search\/orgasm?top&id=67553717","tf":"Orgasm","t":"Orgasm","n":"164,648","w":147,"ty":"search"},{"i":"https:\/\/cdn77-pic.xnxx-cdn.com\/videos\/thumbs169xnxx\/a1\/82\/b6\/a182b64b1a0a5560444aadb027d47f7e\/a182b64b1a0a5560444aadb027d47f7e.2.jpg","c":10,"u":"\/search\/teen?id=48902145","tf":"18","t":"18","n":"222,561","w":146,"ty":"cat","id":13},{"i":"https:\/\/cdn77-pic.xnxx-cdn.com\/videos\/thumbs169xnxx\/1f\/06\/45\/1f0645c1bb2f199bc8a604f991bd0fdd\/1f0645c1bb2f199bc8a604f991bd0fdd.7.jpg","c":10,"u":"\/search\/wife?top&id=40416137","tf":"Wife","t":"Wife","n":"197,011","w":146,"ty":"search"},{"i":"https:\/\/cdn77-pic.xnxx-cdn.com\/videos\/thumbs169xnxx\/0d\/08\/cd\/0d08cd13985a5e5532e410a9f10ed214\/0d08cd13985a5e5532e410a9f10ed214.25.jpg","c":10,"u":"\/search\/toons?id=80720621","tf":"Toons","t":"Toons","n":"45,445","w":145,"ty":"cat","id":49},{"i":"https:\/\/cdn77-pic.xnxx-cdn.com\/videos\/thumbs169xnxx\/cb\/0f\/f1\/cb0ff1f9de30372ace1ee9c5aff206e3-1\/cb0ff1f9de30372ace1ee9c5aff206e3.27.jpg","c":10,"u":"\/search\/deepthroat?top&id=77544971","tf":"Deepthroat","t":"Deepthroat","n":"113,229","w":145,"ty":"search"},{"i":"https:\/\/cdn77-pic.xnxx-cdn.com\/videos\/thumbs169xnxx\/7d\/0e\/02\/7d0e02b62c7bb73ed664dae64b988a54\/7d0e02b62c7bb73ed664dae64b988a54.15.jpg","c":10,"u":"\/search\/real_amateur?id=51598997","tf":"REAL Amateur","t":"REAL Amateur","n":"175,117","w":144,"ty":"cat","id":17},{"i":"https:\/\/cdn77-pic.xnxx-cdn.com\/videos\/thumbs169xnxx\/19\/67\/b9\/1967b9e0a9a15fbfdf4f15ddd4aa0fb2\/1967b9e0a9a15fbfdf4f15ddd4aa0fb2.2.jpg","c":10,"u":"\/search\/pussy?top&id=77001983","tf":"Pussy","t":"Pussy","n":"584,754","w":144," ...
#     </script>
#    </div>
#   </div>
#   <div id="footer">
#    <div id="ad-footer">
#    </div>
#    <div class="remove-ads">
#     <p>
#      <a class="pull-right" href="https://www.xnxx.gold/?pmln=en&amp;sxcaf=8KVUNHU4PG&amp;pmsc=ad">
#       <span class="remove-ads-link">
#        Remove ads
#       </span>
#       <span class="icon-f icf-close">
#       </span>
#      </a>
#      <span class="mobile-only-hide">
#       Ads by
#       <a href="https://www.trafficfactory.com/" target="_blank">
#        TrafficFactory
#       </a>
#      </span>
#     </p>
#    </div>
#    <p id="multi-footer-link">
#     <a href="https://multi.xnxx.com/">
#      XNXX Images
#     </a>
#     /
#     <a href="https://multi.xnxx.com/gifs">
#      Animated Gifs
#     </a>
#     /
#     <a href="https://www.sexstories.com/">
#      Stories
#     </a>
#    </p>
#    <p>
#     We hope you enjoyed our free porn movies and pics!
#     <a href="https://www.xnxx.com" target="_self">
#      Think about bookmarking our site!
#     </a>
#     <br/>
#     If you are not a mature adult or are offended by pornography please don't come back!
#    </p>
#    <p>
#     Have something to say?
#     <a href="https://forum.xnxx.com/">
#      <strong>
#       Please use our Forum
#      </strong>
#     </a>
#     , or
#     <a href="https://info.xnxx.com/contact">
#      <strong>
#       contact us
#      </strong>
#     </a>
#     directly (warning : we can't read every email).
#     <br/>
#     Advertising, Traffic Trades, Sponsors
#     <a href="https://www.trafficfactory.com/" target="_top">
#      Webmasters click here
#     </a>
#     .
# XNXX.COM Copyright 2000-2024. All rights reserved. Thanks for visiting our free sex site.
#     <br/>
#     -
#     <a href="https://info.xnxx.com/legal/tos">
#      Terms of service
#     </a>
#     -
#     <a href="https://info.xnxx.com/legal/privacy">
#      Privacy policy
#     </a>
#     -
#     <a href="https://info.xnxx.com/legal/privacynotice">
#      Privacy notice
#     </a>
#     -
#     <a href="https://info.xnxx.com/content_removal">
#      Content removal
#     </a>
#    </p>
#   </div>
#   <!-- Last Round :  -->
#   <script src="https://static-cdn77.xnxx-cdn.com/v-4e816821dca/v3/js/skins/min/xnxx.footer.static.js">
#   </script>
#   <script src="https://static-cdn77.xnxx-cdn.com/v3/js/libs/jquery.min.js">
#   </script>
#   <script>
#    if(typeof(window.jQuery) === 'undefined') { document.write('<script src="https://static-cdn77.xnxx-cdn.com/v3/js/libs/jquery-1.7.2.min.js"><\/script>'); }
#   </script>
#   <script src="https://static-cdn77.xnxx-cdn.com/v3/js/skins/min/require.static.js">
#   </script>
#   <script>
#    require.onError=function(err){if(xv&&xv.console&&xv.console.logRJS){xv.console.logRJS(err);}else{throw err;}};require.config({"waitSeconds":300,"baseUrl":"https://static-cdn77.xnxx-cdn.com\/v-69de908b9b0\/v3\/js\/","config":{"i18n":{"locale":"en"}}});define("config/main",xv.conf);require(["skins/min/xnxx"]);
#   </script>
#   <script>
#    !function(){var e=function(){if("object"!=typeof xv)return"xv global namespace";var e="/mobile"===window.location.pathname.substring(0,7);if(!e&&"object"!=typeof xv.conf)return"xv config";var t=e?"oldombile":xv.conf.sitename||"",o=!e&&"xnxx"===t&&"object"==typeof xv.conf.data&&"xnxx_contact"===xv.conf.data.action;if(!o&&"object"!=typeof xv.utils)return"header.js";if(!e){var n="object"==typeof xv.conf.data&&"embed"===xv.conf.data.action;if(!("xvideos"!==t&&"xnxx"!==t||n||o||"object"==typeof xv.mobile))return"footer.js";if(!n&&"function"!=typeof jQuery)return"jquery.js";if("function"!=typeof require)return"require.js";if("undefined"==typeof html5player_onlyfake&&window.location.pathname.split("#")[0].match(/^(\/video(\d+|-[\da-z]+)\/[-\w\.\~]+|\/embedframe\/[a-z0-9]+)$/)&&"object"!=typeof html5player)return"player.js"}var r=document.documentElement,a=r.currentStyle?r.currentStyle.fontFamily:!!window.getComputedStyle&&window.getComputedStyle(r,null).getPropertyValue("font-family");return!1!==a&&"sans-serif"!==a&&"skin.css"}();if(!1!==e){var t=["c7","st"],o="c7";if(console.error("Failed to load "+e+" for CDN "+o),t.length<2)return void console.warn("Not enough CDNs available");for(var n in t)if(t[n]===o){n<t.length-1?(n++,o=t[n]):o=t[0];break}console.info("Switching to CDN "+o);var r=new Date((new Date).getTime()+6048e5);document.cookie="static_cdn="+o+";expires="+r.toGMTString()+";path=/;"}}();
#   </script>
#  </body>
# </html>
# <!-- Gen By 19 -->

# %%
for link in soup.find_all('a', attrs={'href': re.compile('^http')}):
    print(link)
# Out:
# <a class="gold-plate" href="https://www.xnxx.gold/gold/videos" id="header-mobile-gold" title="XNXX GOLD">GOLD</a>
# <a class="mobile-show-inline-block header-mobile-link" href="https://cams.xnxx.com/?language=en&amp;mp_code=d4vnm&amp;utm_content=d4vnm" id="header-mobile-live-cam" target="_blank" title="Live Cams"><span class="icon-f icf-xcams"></span> <span class="label sm-col-only-show-inline md-col-only-show-inline">Live Cams</span></a>
# <a class="mobile-show-inline-block header-mobile-link nutaku-games" href="https://xnxx.nutaku.net/wl/gate/" target="_blank" title="Porn Games"><span class="icon-f icf-gamepad"></span> <span class="label md-col-only-show-inline">Porn Games</span></a>
# <a class="mobile-show-inline-block header-mobile-link" href="https://www.xdating.com/" target="_blank"><span class="icon-f icf-hearts-o" title="Dating"></span> <span class="label md-col-only-show-inline">Dating</span></a>
# <a href="https://multi.xnxx.com">Pictures</a>
# <a class="live-cams" href="https://cams.xnxx.com/?language=en&amp;mp_code=d4vni&amp;utm_content=d4vni">Live Cams</a>
# <a href="https://www.sexstories.com">Sex Stories</a>
# <a href="https://forum.xnxx.com">Forum</a>
# <a class="nutaku-games" href="https://xnxx.nutaku.net/wl/gate/" target="_blank">Games</a>
# <a href="https://www.xdating.com/">Dating</a>
# <a class="gold-plate" href="https://www.xnxx.gold/gold/videos?pmsc=menu&amp;pmln=en&amp;sxcaf=8KVUNHU4PG_menu__">GOLD</a>
# <a class="pull-right" href="https://www.xnxx.gold/?pmln=en&amp;sxcaf=8KVUNHU4PG&amp;pmsc=ad"><span class="remove-ads-link">Remove ads</span> <span class="icon-f icf-close"></span></a>
# <a href="https://www.trafficfactory.com/" target="_blank">TrafficFactory</a>
# <a href="https://multi.xnxx.com/">XNXX Images</a>
# <a href="https://multi.xnxx.com/gifs">Animated Gifs</a>
# <a href="https://www.sexstories.com/">Stories</a>
# <a href="https://www.xnxx.com" target="_self">Think about bookmarking our site!</a>
# <a href="https://forum.xnxx.com/"><strong>Please use our Forum</strong></a>
# <a href="https://info.xnxx.com/contact"><strong>contact us</strong></a>
# <a href="https://www.trafficfactory.com/" target="_top">Webmasters click here</a>
# <a href="https://info.xnxx.com/legal/tos">Terms of service</a>
# <a href="https://info.xnxx.com/legal/privacy">Privacy policy</a>
# <a href="https://info.xnxx.com/legal/privacynotice">Privacy notice</a>
# <a href="https://info.xnxx.com/content_removal">Content removal</a>

# %%
type(link)
# Out:
# bs4.element.Tag

# %%
file = open('parsed_data.txt', 'w')
for link in soup.find_all('a', attrs={'href': re.compile('^http')}):
                        soup_link = str(link)
                        print(soup_link)
                        file.write(soup_link + '\n')
file.flush()
file.close()
# Out:
# <a href="https://open.gsa.gov/api/dap/" rel="noopener" target="_blank">API</a>
# <a href="https://analytics.usa.gov/data/live/top-10000-domains-30-days.csv">Download the full dataset.</a>
# <a class="external-link" href="https://digital.gov/guides/dap/">Digital Analytics Program</a>
# <a href="https://open.gsa.gov/api/dap/" rel="noopener" target="_blank">API</a>
# <a class="usa-button usa-button-secondary-inverse margin-y-2" href="https://github.com/18F/analytics.usa.gov/issues">
# <img alt="Github Icon" class="github-icon" src="/images/github-logo-white.svg"/>
#             Suggest a feature or report an issue
#           </a>
# <a href="https://github.com/18F/analytics.usa.gov">
# <img alt="Github Icon" class="github-icon" src="/images/github-logo.svg"/>
#               View application code on GitHub</a>
# <a href="https://github.com/18F/analytics-reporter">
# <img alt="Github Icon" class="github-icon" src="/images/github-logo.svg"/>
#               View code for the data on GitHub</a>
# <a href="https://digital.gov/guides/dap/">Digital Analytics Program</a>
# <a class="usa-identifier__required-link usa-link" href="https://www.gsa.gov/about-us">About GSA</a>
# <a class="usa-identifier__required-link usa-link" href="https://www.gsa.gov/website-information/accessibility-statement">Accessibility statement</a>
# <a class="usa-identifier__required-link usa-link" href="https://www.gsa.gov/reference/freedom-of-information-act-foia">FOIA requests</a>
# <a class="usa-identifier__required-link usa-link" href="https://www.gsa.gov/reference/civil-rights-programs/the-no-fear-act">No FEAR Act data</a>
# <a class="usa-identifier__required-link usa-link" href="https://www.gsaig.gov/">Office of the Inspector
#             General</a>
# <a class="usa-identifier__required-link usa-link" href="https://www.gsa.gov/reference/reports/budget-performance">Performance reports</a>
# <a class="usa-identifier__required-link usa-link" href="https://www.gsa.gov/website-information/website-policies">Privacy policy</a>
# <a class="usa-link" href="https://www.usa.gov/">Visit USA.gov</a>
